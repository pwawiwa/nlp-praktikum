# %% [markdown]
# # Crawling Twitter Data based on **Search Keyword** Using `tweet-harvest`
# Last updated by Helmi Satria (helmisatria.com) on September 22, 2023
#
# Note: **For educational purposes only**

# %% [markdown]
# #1CPMK1- Sub CPMK1.1( bobot : 10 )
# Lakukan crawling data teks dari media sosial/ web dan simpan hasilnya dalam
# bentuk excel/csv. Setiap mahasiswa harus melakukan crawling dengan kata kunci
# tertentu. Kata kunci tidak boleh sama dengan mahasiswa lainnya.

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [553 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,130 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,305 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,009 kB]
# ...

# %%
# Crawl Data

filename = 'judi slot.csv'
search_keyword = 'judi slot'
limit = 200

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"/content/tweets-data/judi_slot.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Fri Oct 20 10:13:04 +0000 2023  1715310154210771279
# 1    Fri Oct 20 10:11:35 +0000 2023  1715309782540972404
# 2    Fri Oct 20 10:02:28 +0000 2023  1715307488038596630
# 3    Fri Oct 20 10:02:15 +0000 2023  1715307430748254674
# 4    Fri Oct 20 09:54:00 +0000 2023  1715305358254862343
# ..                              ...                  ...
# 161  Thu Oct 19 19:06:55 +0000 2023  1715082113777840555
# 162  Thu Oct 19 19:05:11 +0000 2023  1715081679830954449
# 163  Thu Oct 19 18:57:13 +0000 2023  1715079674785869930
# 164  Thu Oct 19 18:51:55 +0000 2023  1715078340418367892
# 165  Thu Oct 19 18:23:49 +0000 2023  1715071269308092797
#
#                                              full_text  quote_count  \
# 0    🌟 RESULT SUNDA 🌟 HARI: JUMAT, 20 OKTOBER 2023 ...            0
# 1    AGEN SLOT GACOR HARI INI ASTABET  Jepri Asahi ...            0
# 2    🌟 RESULT LAMPUNG 🌟 HARI: JUMAT, 20 OKTOBER 202...            0
# ...

# %%
text = df['full_text']

# %%
text
# Out:
# 0      🌟 RESULT SUNDA 🌟 HARI: JUMAT, 20 OKTOBER 2023 ...
# 1      AGEN SLOT GACOR HARI INI ASTABET  Jepri Asahi ...
# 2      🌟 RESULT LAMPUNG 🌟 HARI: JUMAT, 20 OKTOBER 202...
# 3                  Masih banyak yg maen judi slot online
# 4                                     @UnfaedahKeras 🔥🔥🔥
#                              ...
# 161    🌟 RESULT CAROLINA DAYS🌟 HARI: JUMAT, 20 OKTOBE...
# 162    Mau ngusut judi slot fraud manipulasi data ehh...
# 163    🌟 RESULT WATFORD🌟 HARI: JUMAT, 20 OKTOBER 2023...
# 164    🌟 RESULT CHINA NIGHT🌟 HARI: JUMAT, 20 OKTOBER ...
# 165    kita harus hormati presiden 2 periode yang dip...
# Name: full_text, Length: 166, dtype: object

# %%
import re

# %% [markdown]
# # 2. CPMK1- Sub CPMK1.1. (25)
# Lakukan pembersihan meliputi penghapusan punctuation, angka dan karakter yang
# tidak penting menggunakan menggunakan regex.
# Simpan hasilnya menjadi file csv/excel.

# %%
def remove_punctuation_and_numbers(text):
    cleaned_text = re.sub(r'[^a-zA-Z\s]', '', text)
    return cleaned_text

# Menggunakan fungsi pada setiap baris dalam DataFrame
df['Cleaned_Text'] = text.apply(remove_punctuation_and_numbers)

print(df)
# Out:
#                          created_at               id_str  \
# 0    Fri Oct 20 10:13:04 +0000 2023  1715310154210771279
# 1    Fri Oct 20 10:11:35 +0000 2023  1715309782540972404
# 2    Fri Oct 20 10:02:28 +0000 2023  1715307488038596630
# 3    Fri Oct 20 10:02:15 +0000 2023  1715307430748254674
# 4    Fri Oct 20 09:54:00 +0000 2023  1715305358254862343
# ..                              ...                  ...
# 161  Thu Oct 19 19:06:55 +0000 2023  1715082113777840555
# 162  Thu Oct 19 19:05:11 +0000 2023  1715081679830954449
# 163  Thu Oct 19 18:57:13 +0000 2023  1715079674785869930
# 164  Thu Oct 19 18:51:55 +0000 2023  1715078340418367892
# 165  Thu Oct 19 18:23:49 +0000 2023  1715071269308092797
#
#                                              full_text  quote_count  \
# 0    🌟 RESULT SUNDA 🌟 HARI: JUMAT, 20 OKTOBER 2023 ...            0
# 1    AGEN SLOT GACOR HARI INI ASTABET  Jepri Asahi ...            0
# 2    🌟 RESULT LAMPUNG 🌟 HARI: JUMAT, 20 OKTOBER 202...            0
# ...

# %%
data_bersih = df['Cleaned_Text']

# %%
data_bersih.to_csv('Review judi.csv')

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# # CPMK1- Sub CPMK1.2.
# a. Lakukan parsing dan simpan hasilnya dalam bentuk excel/csv (bobot:10)

# %%
import spacy

# %%
# Parsing
nlp = spacy.load("en_core_web_sm")
df['Parsed_Text'] = df['Cleaned_Text'].apply(lambda text: nlp(text))

# %%
parsed = df['Parsed_Text']

# %%
parsed
# Out:
# 0      ( , RESULT, SUNDA,  , HARI, JUMAT,  , OKTOBER,...
# 1      (AGEN, SLOT, GACOR, HARI, INI, ASTABET,  , Jep...
# 2      ( , RESULT, LAMPUNG,  , HARI, JUMAT,  , OKTOBE...
# 3          (Masih, banyak, yg, maen, judi, slot, online)
# 4                                        (UnfaedahKeras)
#                              ...
# 161    ( , RESULT, CAROLINA, DAYS, HARI, JUMAT,  , OK...
# 162    (Mau, ngusut, judi, slot, fraud, manipulasi, d...
# 163    ( , RESULT, WATFORD, HARI, JUMAT,  , OKTOBER, ...
# 164    ( , RESULT, CHINA, NIGHT, HARI, JUMAT,  , OKTO...
# 165    (kita, harus, hormati, presiden,  , periode, y...
# Name: Parsed_Text, Length: 166, dtype: object

# %%
parsed.to_csv('parsed Review judi.csv')

# %%
from nltk.tokenize import word_tokenize
import nltk

# %%
kamus_kbbi = pd.read_csv('/content/stopwords.csv')['Slangwords'].tolist()

# %%
slangwords = kamus_kbbi

# %%
slangwords =kamus_kbbi

# %%
df['Parsed_Text']
# Out:
# 0      ( , RESULT, SUNDA,  , HARI, JUMAT,  , OKTOBER,...
# 1      (AGEN, SLOT, GACOR, HARI, INI, ASTABET,  , Jep...
# 2      ( , RESULT, LAMPUNG,  , HARI, JUMAT,  , OKTOBE...
# 3          (Masih, banyak, yg, maen, judi, slot, online)
# 4                                        (UnfaedahKeras)
#                              ...
# 161    ( , RESULT, CAROLINA, DAYS, HARI, JUMAT,  , OK...
# 162    (Mau, ngusut, judi, slot, fraud, manipulasi, d...
# 163    ( , RESULT, WATFORD, HARI, JUMAT,  , OKTOBER, ...
# 164    ( , RESULT, CHINA, NIGHT, HARI, JUMAT,  , OKTO...
# 165    (kita, harus, hormati, presiden,  , periode, y...
# Name: Parsed_Text, Length: 166, dtype: object

# %%
parsed_data= str(parsed).lower()

# %%
parsed_data
# Out:
# '0      ( , result, sunda,  , hari, jumat,  , oktober,...\n1      (agen, slot, gacor, hari, ini, astabet,  , jep...\n2      ( , result, lampung,  , hari, jumat,  , oktobe...\n3          (masih, banyak, yg, maen, judi, slot, online)\n4                                        (unfaedahkeras)\n                             ...                        \n161    ( , result, carolina, days, hari, jumat,  , ok...\n162    (mau, ngusut, judi, slot, fraud, manipulasi, d...\n163    ( , result, watford, hari, jumat,  , oktober, ...\n164    ( , result, china, night, hari, jumat,  , okto...\n165    (kita, harus, hormati, presiden,  , periode, y...\nname: parsed_text, length: 166, dtype: object'

# %%
def find_slang(text):
    found_slang = [word for word in slangwords if word in text]
    return found_slang

# %%
parsed_data
# Out:
# '0      ( , result, sunda,  , hari, jumat,  , oktober,...\n1      (agen, slot, gacor, hari, ini, astabet,  , jep...\n2      ( , result, lampung,  , hari, jumat,  , oktobe...\n3          (masih, banyak, yg, maen, judi, slot, online)\n4                                        (unfaedahkeras)\n                             ...                        \n161    ( , result, carolina, days, hari, jumat,  , ok...\n162    (mau, ngusut, judi, slot, fraud, manipulasi, d...\n163    ( , result, watford, hari, jumat,  , oktober, ...\n164    ( , result, china, night, hari, jumat,  , okto...\n165    (kita, harus, hormati, presiden,  , periode, y...\nname: parsed_text, length: 166, dtype: object'

# %% [markdown]
# # 3b.Carilah kata-kata slangword yang ada dalam dataset Anda, dengan cara
# mencocokan dengan kamus KBBI (terlampir). Simpan hasilnya dalam bentuk
# csv/excel. Tampilkan 100 kata slang yang Anda dapatkan dan tampilkan dalam
# bentuk Gunakan (bobot:25)

# %%
slangwords
# Out:
# ['Adam',
#  'Aga',
#  'Agustus',
#  'Ahad',
#  'Ajisaka',
#  'Akad',
#  'Akuarius',
#  'Alip',
#  'Aljalil',
#  'Alkabir',
#  'Alkadim',
#  'Alkadir',
#  'Alkasyaf',
#  'Alkitab',
#  'Alkus',
#  'Allah',
#  'Allahuma',
#  'Almalik',
#  'Almasih',
#  'Alquran',
#  'Anda',
#  'Andalas',
#  'Anggorokasih',
#  'April',
#  'Arab',
#  'Aria',
#  'Aries',
#  'Asyera',
#  'Asytoret',
#  'Asyura',
#  'Avesta',
#  'Baal',
#  'Babet',
#  'Badui',
#  'Baitulharam',
#  'Baitullah',
#  'Baitulmakdis',
#  'Baitulmakmur',
#  'Baitulmukadas',
#  'Baitulmukadis',
#  'Baruna',
#  'Batak',
#  'Be',
#  'Belanda',
#  'Bibel',
#  'Brahma',
#  'Buddha',
#  'Buddhis',
#  'Buddhisme',
#  'Burjusumbulat',
#  'Cakrabirawa',
#  'Celsius',
#  'Cina',
#  'Cokorda',
#  'Dal',
#  'Danuh',
#  'Delu',
#  'Desember',
#  'Deuterokanonika',
#  'Digul',
#  'Ehe',
#  'Eurasia',
#  'Fahrenheit',
#  'Februari',
#  'Galungan',
#  'Gemini',
#  'Habsyi',
#  'Hamal',
#  'Hambali',
#  'Hanafi',
#  'Hinayana',
#  'Hindi',
# ...

# %%
import re

# Hapus semua simbol kecuali huruf dan angka
parsed_data_bersih = re.sub(r'[^a-zA-Z0-9\s]', '', parsed_data)

# Output string yang sudah dibersihkan
print(parsed_data_bersih)
# Out:
# 0        result sunda   hari jumat   oktober
# 1      agen slot gacor hari ini astabet   jep
# 2        result lampung   hari jumat   oktobe
# 3          masih banyak yg maen judi slot online
# 4                                        unfaedahkeras
#
# 161      result carolina days hari jumat   ok
# 162    mau ngusut judi slot fraud manipulasi d
# 163      result watford hari jumat   oktober
# 164      result china night hari jumat   okto
# 165    kita harus hormati presiden   periode y
# name parsedtext length 166 dtype object

# %%
one_line_string = ' '.join(parsed_data_bersih.split())

# %%
one_line_string
# Out:
# '0 result sunda hari jumat oktober 1 agen slot gacor hari ini astabet jep 2 result lampung hari jumat oktobe 3 masih banyak yg maen judi slot online 4 unfaedahkeras 161 result carolina days hari jumat ok 162 mau ngusut judi slot fraud manipulasi d 163 result watford hari jumat oktober 164 result china night hari jumat okto 165 kita harus hormati presiden periode y name parsedtext length 166 dtype object'

# %%
slangwords
# Out:
# ['Adam',
#  'Aga',
#  'Agustus',
#  'Ahad',
#  'Ajisaka',
#  'Akad',
#  'Akuarius',
#  'Alip',
#  'Aljalil',
#  'Alkabir',
#  'Alkadim',
#  'Alkadir',
#  'Alkasyaf',
#  'Alkitab',
#  'Alkus',
#  'Allah',
#  'Allahuma',
#  'Almalik',
#  'Almasih',
#  'Alquran',
#  'Anda',
#  'Andalas',
#  'Anggorokasih',
#  'April',
#  'Arab',
#  'Aria',
#  'Aries',
#  'Asyera',
#  'Asytoret',
#  'Asyura',
#  'Avesta',
#  'Baal',
#  'Babet',
#  'Badui',
#  'Baitulharam',
#  'Baitullah',
#  'Baitulmakdis',
#  'Baitulmakmur',
#  'Baitulmukadas',
#  'Baitulmukadis',
#  'Baruna',
#  'Batak',
#  'Be',
#  'Belanda',
#  'Bibel',
#  'Brahma',
#  'Buddha',
#  'Buddhis',
#  'Buddhisme',
#  'Burjusumbulat',
#  'Cakrabirawa',
#  'Celsius',
#  'Cina',
#  'Cokorda',
#  'Dal',
#  'Danuh',
#  'Delu',
#  'Desember',
#  'Deuterokanonika',
#  'Digul',
#  'Ehe',
#  'Eurasia',
#  'Fahrenheit',
#  'Februari',
#  'Galungan',
#  'Gemini',
#  'Habsyi',
#  'Hamal',
#  'Hambali',
#  'Hanafi',
#  'Hinayana',
#  'Hindi',
# ...

# %%
# Memisahkan kata-kata dalam string
words = one_line_string.split()

# Mencocokkan kata-kata slang dengan kamus slangwords
slang_matches = [word for word in words if word in slangwords]

# Cetak kata-kata slang yang cocok
print("Kata-kata slang yang cocok:", slang_matches)
# Out:
# Kata-kata slang yang cocok: ['hari', 'agen', 'hari', 'ini', 'lampung', 'hari', 'masih', 'banyak', 'judi', 'hari', 'mau', 'judi', 'manipulasi', 'hari', 'hari', 'kita', 'harus', 'presiden', 'periode']

# %%
slang_matches
# Out:
# ['hari',
#  'agen',
#  'hari',
#  'ini',
#  'lampung',
#  'hari',
#  'masih',
#  'banyak',
#  'judi',
#  'hari',
#  'mau',
#  'judi',
#  'manipulasi',
#  'hari',
#  'hari',
#  'kita',
#  'harus',
#  'presiden',
#  'periode']

# %%
slang_words = pd.DataFrame(slang_matches, columns=['slang_words'])

# %%
slang_words.to_csv('slang_words.csv')

# %%
from nltk.corpus import stopwords

# %% [markdown]
# # 3.c Lakukan tokenizing berdasarkan hasil 3b, simpan hasilnya dalam bentuk
# csv/excel dan tampilkan 100 token pertama. (bobot:10)

# %%
tokenize_slang =pd.DataFrame(slang_matches, columns=['hasil'])

# %%
tokenize_slang.to_csv('tokenize_slang.csv')

# %% [markdown]
# # Hasil telah ter tokenizasi by word

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords = stopwords.words('indonesian')
stopwords
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
# ...

# %%
# !pip install Sastrawi
# Out:
# ...
#   Using cached Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
# ...

# %% [markdown]
# # 3d. Lakukan stopword removing berdasarkan hasil 3c, simpan hasilnya dalam
# bentuk csv/excel. (bobot:10)

# %%
import Sastrawi

# %%
slang_words
# Out:
#    slang_words
# 0         hari
# 1         agen
# 2         hari
# 3          ini
# 4      lampung
# 5         hari
# 6        masih
# 7       banyak
# 8         judi
# 9         hari
# 10         mau
# 11        judi
# 12  manipulasi
# 13        hari
# 14        hari
# 15        kita
# 16       harus
# 17    presiden
# 18     periode

# %%
teks = slang_matches

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory  import StopWordRemoverFactory
import re
def remove_stopword(words):
  factory = StopWordRemoverFactory()
  stopword_remover = factory.create_stop_word_remover()
  processed_words = [stopword_remover.remove(word) for word in words]
  return processed_words

# %%
processed_texts = remove_stopword(teks)

# %%
processed_texts
# Out:
# ['hari',
#  'agen',
#  'hari',
#  '',
#  'lampung',
#  'hari',
#  '',
#  'banyak',
#  'judi',
#  'hari',
#  'mau',
#  'judi',
#  'manipulasi',
#  'hari',
#  'hari',
#  '',
#  '',
#  'presiden',
#  'periode']

# %%
clean_processed_texts= [item for item in processed_texts if item != '']

print(clean_processed_texts)
# Out:
# ['hari', 'agen', 'hari', 'lampung', 'hari', 'banyak', 'judi', 'hari', 'mau', 'judi', 'manipulasi', 'hari', 'hari', 'presiden', 'periode']

# %% [markdown]
# # 3.e Lakukan stemming berdasarkan hasil 3d dan tampilkan 100 stem pertama.
# (bobot:10)

# %%
#3.e Stemming

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Buat objek stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Kata yang akan di-stem
kata = clean_processed_texts

stemmed_kata = [stemmer.stem(kata) for kata in kata]

# Output kata-kata yang telah di-stem
print(stemmed_kata)
# Out:
# ['hari', 'agen', 'hari', 'lampung', 'hari', 'banyak', 'judi', 'hari', 'mau', 'judi', 'manipulasi', 'hari', 'hari', 'presiden', 'periode']

# %%
# output tidak ada kata yang dapat distem
